# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("housing_data.csv")

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90    NaN  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99    NaN  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# std     27.999513    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.175000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     76.800000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     93.975000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  486.000000  506.000000
# mean    12.715432   22.532806
# std      7.155871    9.197104
# min      1.730000    5.000000
# 25%      7.125000   17.025000
# 50%     11.430000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
df.shape
# Out:
# (506, 14)

# %%
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
average_value=df['CRIM'].mean() 
average_value=df['ZN'].mean() 
average_value=df['INDUS'].mean() 
average_value=df['CHAS'].mean() 
average_value=df['AGE'].mean() 
average_value=df['LSTAT'].mean()

# %%
df['CRIM'].fillna(average_value,inplace=True)
df['ZN'].fillna(average_value,inplace=True)
df['INDUS'].fillna(average_value,inplace=True)
df['CHAS'].fillna(average_value,inplace=True)
df['AGE'].fillna(average_value,inplace=True)
df['LSTAT'].fillna(average_value,inplace=True)

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
plt.figure(figsize=(12,12))
sns.heatmap(data=df.corr().round(2),annot=True,cmap='coolwarm',linewidths=0.2,square=True)
# Out:
# <Axes: >

# %%
df1 = df[['RM','TAX','PTRATIO','LSTAT','MEDV']]
df1.head()
# Out:
#       RM  TAX  PTRATIO      LSTAT  MEDV
# 0  6.575  296     15.3   4.980000  24.0
# 1  6.421  242     17.8   9.140000  21.6
# 2  7.185  242     17.8   4.030000  34.7
# 3  6.998  222     18.7   2.940000  33.4
# 4  7.147  222     18.7  12.715432  36.2

# %%
sns.pairplot(data=df1)

# %%
desc = df1.describe().round(2) 
desc
# Out:
#            RM     TAX  PTRATIO   LSTAT    MEDV
# count  506.00  506.00   506.00  506.00  506.00
# mean     6.28  408.24    18.46   12.72   22.53
# std      0.70  168.54     2.16    7.01    9.20
# min      3.56  187.00    12.60    1.73    5.00
# 25%      5.89  279.00    17.40    7.23   17.02
# 50%      6.21  330.00    19.05   12.00   21.20
# 75%      6.62  666.00    20.20   16.57   25.00
# max      8.78  711.00    22.00   37.97   50.00

# %%
plt.figure(figsize=(20,3)) 
plt.subplot(1,2,1) 
sns.boxplot(df1.MEDV,color='#005030') 
plt.title('Box Plot of MEDV') 
plt.subplot(1,2,2) 
sns.distplot(a=df1.MEDV,color='#500050') 
plt.title('Distribution Plot of MEDV') 
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_22088\2912508024.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=df1.MEDV,color='#500050')

# %%
MEDV_Q3 = desc['MEDV']['75%'] 
MEDV_Q1 = desc['MEDV']['25%'] 
MEDV_IQR = MEDV_Q3 - MEDV_Q1 
MEDV_UV = MEDV_Q3 + 1.5*MEDV_IQR 
MEDV_LV = MEDV_Q1 - 1.5*MEDV_IQR 
df1[df1['MEDV']<MEDV_LV]
# Out:
#         RM  TAX  PTRATIO  LSTAT  MEDV
# 398  5.453  666     20.2  30.59   5.0
# 405  5.683  666     20.2  22.98   5.0

# %%
df1[df1['MEDV']>MEDV_UV].sort_values(by=['MEDV','RM'])
# Out:
#         RM  TAX  PTRATIO      LSTAT  MEDV
# 190  6.951  398     15.2   5.100000  37.0
# 179  6.980  193     17.8   5.040000  37.2
# 291  7.148  245     19.2   3.560000  37.3
# 226  8.040  307     17.4  12.715432  37.6
# 182  7.155  193     17.8   4.820000  37.9
# 97   8.069  276     18.0   4.210000  38.7
# 180  7.765  193     17.8   7.560000  39.8
# 157  6.943  403     14.7   4.590000  41.3
# 232  8.337  307     17.4   2.470000  41.7
# 202  7.610  348     14.7   3.110000  42.3
# 253  8.259  330     19.1   3.540000  42.8
# 261  7.520  264     13.0   7.260000  43.1
# 268  7.470  264     13.0   3.160000  43.5
# 98   7.820  276     18.0   3.570000  43.8
# 256  7.454  244     15.9   3.110000  44.0
# 224  8.266  307     17.4   4.140000  44.8
# 280  7.820  216     14.9   3.760000  45.4
# 282  7.645  216     14.9   3.010000  46.0
# 228  7.686  307     17.4  12.715432  46.7
# 233  8.247  307     17.4   3.950000  48.3
# 203  7.853  224     14.7   3.810000  48.5
# 262  8.398  264     13.0   5.910000  48.8
# 368  4.970  666     20.2   3.260000  50.0
# 372  5.875  666     20.2   8.880000  50.0
# 371  6.216  666     20.2   9.530000  50.0
# 369  6.683  666     20.2   3.730000  50.0
# 370  7.016  666     20.2   2.960000  50.0
# 161  7.489  403     14.7   1.730000  50.0
# 162  7.802  403     14.7   1.920000  50.0
# 186  7.831  193     17.8   4.450000  50.0
# 195  7.875  255     14.4   2.970000  50.0
# 283  7.923  198     13.6   3.160000  50.0
# 166  7.929  403     14.7   3.700000  50.0
# 204  8.034  224     14.7   2.880000  50.0
# 267  8.297  264     13.0   7.440000  50.0
# 163  8.375  403     14.7   3.320000  50.0
# 257  8.704  264     13.0   5.120000  50.0
# 225  8.725  307     17.4   4.630000  50.0

# %%
print(f'Shape of dataset before removing outliers: {df1.shape}')
df2 = df1[~(df1['MEDV']==50)]
print(f'Shape of dataset after remving Outliers: {df2.shape}')
# Out:
# Shape of dataset before removing outliers: (506, 5)
# Shape of dataset after remving Outliers: (490, 5)

# %%
plt.figure(figsize=(20,3)) 
plt.subplot(1,3,1) 
sns.boxplot(df2.TAX,color='#005030') 
plt.title('Box Plot of TAX') 
plt.subplot(1,3,2) 
sns.distplot(a=df2.TAX,color='#500050')
plt.title('Distribution Plot of TAX') 
plt.subplot(1,3,3) 
sns.scatterplot(df2.TAX,df2.MEDV) 
plt.title('Scatter Plot of TAX vs MEDV') 
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_22088\218946243.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=df2.TAX,color='#500050')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 9
#       7 plt.title('Distribution Plot of TAX')
#       8 plt.subplot(1,3,3)
# ----> 9 sns.scatterplot(df2.TAX,df2.MEDV)
#      10 plt.title('Scatter Plot of TAX vs MEDV')
#      11 plt.show()
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 were given

# %%
temp_df = df2[df1['TAX']>600].sort_values(by=['RM','MEDV']) 
temp_df.shape
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_22088\1990523101.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = df2[df1['TAX']>600].sort_values(by=['RM','MEDV'])
# (132, 5)

# %%
temp_df
# Out:
#         RM  TAX  PTRATIO      LSTAT  MEDV
# 365  3.561  666     20.2   7.120000  27.5
# 367  3.863  666     20.2  13.330000  23.1
# 406  4.138  666     20.2  23.340000  11.9
# 374  4.138  666     20.2  37.970000  13.8
# 384  4.368  666     20.2  30.630000   8.8
# ..     ...  ...      ...        ...   ...
# 473  6.980  666     20.2  12.715432  29.8
# 482  7.061  666     20.2   7.010000  25.0
# 375  7.313  666     20.2  13.440000  15.0
# 453  7.393  666     20.2  16.740000  17.8
# 364  8.780  666     20.2   5.290000  21.9
#
# [132 rows x 5 columns]

# %%
temp_df.describe()
# Out:
#                RM         TAX     PTRATIO       LSTAT        MEDV
# count  132.000000  132.000000  132.000000  132.000000  132.000000
# mean     6.000689  667.704545   20.196212   18.887292   14.994697
# std      0.712621    8.623365    0.019163    6.529482    5.405825
# min      3.561000  666.000000   20.100000    5.290000    5.000000
# 25%      5.674250  666.000000   20.200000   14.175000   10.900000
# 50%      6.139500  666.000000   20.200000   17.910000   14.100000
# 75%      6.407250  666.000000   20.200000   23.052500   19.200000
# max      8.780000  711.000000   20.200000   37.970000   29.800000

# %%
plt.figure(figsize=(20,3)) 
plt.subplot(1,3,1) 
sns.boxplot(df2.PTRATIO,color='#005030') 
plt.title('Box Plot of PTRATIO') 
plt.subplot(1,3,2) 
sns.distplot(a=df2.PTRATIO,color='#500050') 
plt.title('Distribution Plot of PTRATIO') 
plt.subplot(1,3,3) 
sns.scatterplot(df2.PTRATIO,df2.MEDV) 
plt.title('Scatter Plot of PTRATIO vs MEDV') 
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_22088\1053550729.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=df2.PTRATIO,color='#500050')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 9
#       7 plt.title('Distribution Plot of PTRATIO')
#       8 plt.subplot(1,3,3)
# ----> 9 sns.scatterplot(df2.PTRATIO,df2.MEDV)
#      10 plt.title('Scatter Plot of PTRATIO vs MEDV')
#      11 plt.show()
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 were given

# %%
LSTAT_Q3 = desc['LSTAT']['75%'] 
LSTAT_Q1 = desc['LSTAT']['25%'] 
LSTAT_IQR = LSTAT_Q3 - LSTAT_Q1 
LSTAT_UV = LSTAT_Q3 + 1.5*LSTAT_IQR 
LSTAT_LV = LSTAT_Q1 - 1.5*LSTAT_IQR 
df2[df2['LSTAT']>LSTAT_UV].sort_values(by='LSTAT')
# Out:
#         RM  TAX  PTRATIO  LSTAT  MEDV
# 398  5.453  666     20.2  30.59   5.0
# 388  4.880  666     20.2  30.62  10.2
# 384  4.368  666     20.2  30.63   8.8
# 48   5.399  233     17.9  30.81  14.4
# 385  5.277  666     20.2  30.81   7.2
# 387  5.000  666     20.2  31.99   7.4
# 438  5.935  666     20.2  34.02   8.4
# 412  4.628  666     20.2  34.37  17.9
# 141  5.019  437     21.2  34.41  14.4
# 373  4.906  666     20.2  34.77  13.8
# 414  4.519  666     20.2  36.98   7.0
# 374  4.138  666     20.2  37.97  13.8

# %%
plt.figure(figsize=(20,3)) 
plt.subplot(1,3,1) 
sns.boxplot(df2.LSTAT,color='#005030') 
plt.title('Box Plot of LSTAT') 
plt.subplot(1,3,2) 
sns.distplot(a=df2.LSTAT,color='#500050') 
plt.title('Distribution Plot of LSTAT') 
plt.subplot(1,3,3) 
sns.scatterplot(df2.LSTAT,df2.MEDV) 
plt.title('Scatter Plot of LSTAT vs MEDV') 
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_22088\1580814009.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=df2.LSTAT,color='#500050')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 9
#       7 plt.title('Distribution Plot of LSTAT')
#       8 plt.subplot(1,3,3)
# ----> 9 sns.scatterplot(df2.LSTAT,df2.MEDV)
#      10 plt.title('Scatter Plot of LSTAT vs MEDV')
#      11 plt.show()
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 were given
